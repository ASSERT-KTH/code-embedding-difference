# %%
import os
import pickle
from datasets import Dataset
from datasets import load_dataset
output_dir = "/mimer/NOBACKUP/groups/naiss2025-5-243/Embeddings_RBR/diff_embeddings"
all_diffs = []

for i in range(23):
    filename = f"diff_embeddings_chunk_{i:04d}.pkl"
    filepath = os.path.join(output_dir, filename)

    with open(filepath, "rb") as f:
        chunk = pickle.load(f)
        all_diffs.extend(chunk)

# %%
dataset = load_dataset(
    "ASSERT-KTH/RunBugRun-Final",
    split="train"
)

buggy = dataset['buggy_code']
fixed = dataset['fixed_code']

bug_label = dataset['labels']
language = dataset['language']
bug_label = bug_label[:len(all_diffs)]
language = language[:len(all_diffs)]

change_count = []
for i in bug_label:
    if i == None:
        change_count.append(0)
    else: 
        change_count.append(len(i))
# Out:
# Repo card metadata block was not found. Setting CardData to empty.

# %%
new_diffs = []
new_change_count = []
new_bug_label = []

for i in range(len(all_diffs)):
    if change_count[i] > 15 or change_count[i] == 0:
        continue
    else:
        new_diffs.append(all_diffs[i])
        new_change_count.append(change_count[i])
        new_bug_label.append(bug_label[i])

cpp_diffs = []
cpp_change = []
cpp_bug_label = []

for i in range(len(new_diffs)):
    if language[i] == 'cpp':
        cpp_diffs.append(new_diffs[i])
        cpp_change.append(new_change_count[i])
        cpp_bug_label.append(new_bug_label[i])

# %%
flat = [item for sublist in cpp_bug_label for item in sublist]
unique_strings = sorted(set(flat))
string_to_int = {s: i+1 for i, s in enumerate(unique_strings)}
mapped_data = [[string_to_int[s] for s in sublist] for sublist in cpp_bug_label]

# %%
from collections import Counter

flat_numbers = [n for sublist in mapped_data for n in sublist]
distribution = Counter(flat_numbers)
print(distribution)
# Out:
# Counter({14: 56330, 31: 55533, 86: 43812, 57: 39594, 82: 35231, 103: 31530, 74: 30853, 95: 28469, 10: 26610, 42: 25789, 58: 19644, 102: 13260, 129: 13119, 105: 12675, 12: 12383, 55: 12021, 2: 10649, 56: 10241, 118: 9434, 127: 8911, 68: 8642, 43: 8607, 97: 8526, 22: 7546, 20: 6416, 49: 6309, 125: 5964, 13: 5878, 128: 5782, 41: 5712, 83: 5621, 101: 5621, 11: 4217, 84: 4193, 100: 4193, 1: 3820, 104: 3289, 120: 3229, 87: 2345, 79: 2253, 107: 2068, 61: 1565, 29: 1507, 32: 1507, 35: 1424, 109: 1372, 53: 1287, 28: 1164, 33: 1164, 59: 1130, 9: 1130, 75: 1069, 122: 920, 112: 873, 93: 870, 47: 860, 119: 798, 126: 794, 30: 789, 52: 669, 66: 637, 27: 621, 73: 595, 60: 585, 8: 585, 36: 578, 26: 511, 63: 502, 7: 457, 121: 408, 99: 398, 37: 331, 91: 285, 65: 283, 34: 258, 46: 258, 96: 230, 76: 222, 67: 222, 45: 212, 88: 194, 3: 181, 70: 181, 48: 157, 62: 144, 78: 141, 54: 113, 77: 112, 21: 106, 38: 100, 106: 98, 39: 93, 116: 89, 85: 79, 115: 68, 50: 64, 16: 59, 15: 40, 44: 38, 80: 33, 64: 31, 4: 29, 69: 29, 108: 22, 123: 21, 40: 21, 124: 20, 25: 18, 19: 16, 114: 15, 98: 15, 17: 12, 81: 10, 6: 6, 71: 6, 117: 6, 51: 6, 5: 5, 72: 5, 94: 5, 92: 5, 90: 5, 89: 4, 24: 4, 110: 4, 23: 3, 113: 2, 111: 2, 18: 1})

# %%
# HYPERPARAMETER SEARCH, adjust micro for macro or otherway around depending on usecase

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.metrics import f1_score

cpp_diffs = np.array(cpp_diffs)

all_labels = sorted(set(l for sample in mapped_data for l in sample))
label_to_idx = {label: idx for idx, label in enumerate(all_labels)}
idx_to_label = {idx: label for label, idx in label_to_idx.items()}
n_labels = len(label_to_idx)


n_samples = len(mapped_data)
y_multi_hot = np.zeros((n_samples, n_labels), dtype=np.float32)
for i, labels in enumerate(mapped_data):
    for label in labels:
        y_multi_hot[i, label_to_idx[label]] = 1.0


X_temp, X_test, y_temp, y_test = train_test_split(cpp_diffs, y_multi_hot, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.2, random_state=42)

class MultiLabelDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X).float()
        self.y = torch.from_numpy(y).float()
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class MultiLabelNN(nn.Module):
    def __init__(self, input_dim, hidden1, hidden2, dropout, output_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden1, hidden2),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden2, output_dim),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.net(x)

param_grid = {
    'lr': [1e-3, 5e-4],
    'dropout': [0.3, 0.4, 0.5],
    'hidden1': [4096, 2048, 1024, 512],
    'hidden2': [4096, 2048, 1024, 512],
    'batch_size': [128, 256],
}
grid = list(ParameterGrid(param_grid))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_dim = X_train.shape[1]
n_epochs = 10

best_f1 = 0.0
best_params = None

for config in grid:
    print(f"\nTraining with config: {config}")

    train_ds = MultiLabelDataset(X_train, y_train)
    val_ds = MultiLabelDataset(X_val, y_val)

    train_dl = DataLoader(train_ds, batch_size=config['batch_size'], shuffle=True, num_workers=2)
    val_dl = DataLoader(val_ds, batch_size=config['batch_size'], num_workers=2)

    model = MultiLabelNN(input_dim=input_dim,
                         hidden1=config['hidden1'],
                         hidden2=config['hidden2'],
                         dropout=config['dropout'],
                         output_dim=n_labels).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=config['lr'])
    criterion = nn.BCELoss()

    for epoch in range(n_epochs):
        model.train()
        for xb, yb in train_dl:
            xb = xb.to(device)
            yb = yb.to(device)
            optimizer.zero_grad()
            preds = model(xb)
            loss = criterion(preds, yb)
            loss.backward()
            optimizer.step()

    model.eval()
    all_val_preds = []
    all_val_targets = []
    with torch.no_grad():
        for xb, yb in val_dl:
            xb = xb.to(device)
            yb = yb.to(device)
            preds = model(xb)
            all_val_preds.append(preds.cpu())
            all_val_targets.append(yb.cpu())

    val_preds = torch.cat(all_val_preds).numpy()
    val_targets = torch.cat(all_val_targets).numpy()
    val_preds_bin = (val_preds >= 0.5).astype(int)
    val_f1 = f1_score(val_targets, val_preds_bin, average='micro', zero_division=0)

    print(f"Val F1: {val_f1:.4f}")

    if val_f1 > best_f1:
        best_f1 = val_f1
        best_params = config

print("\nBest Config:")
print(best_params)
print(f"Best Validation F1: {best_f1:.4f}")
# Out:
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 4096, 'lr': 0.001}
# Exception ignored in: <function _releaseLock at 0x14797a63bba0>
# Traceback (most recent call last):
#   File "/apps/Arch/software/Python/3.11.3-GCCcore-12.3.0/lib/python3.11/logging/__init__.py", line 237, in _releaseLock
#     def _releaseLock():
#
# KeyboardInterrupt:
# Val F1: 0.7591
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 4096, 'lr': 0.0005}
# Val F1: 0.7528
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 2048, 'lr': 0.001}
# Val F1: 0.7520
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 2048, 'lr': 0.0005}
# Val F1: 0.7407
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 1024, 'lr': 0.001}
# Val F1: 0.7416
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 1024, 'lr': 0.0005}
# Val F1: 0.7325
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 512, 'lr': 0.001}
# Val F1: 0.7281
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 512, 'lr': 0.0005}
# Val F1: 0.7057
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 256, 'lr': 0.001}
# Val F1: 0.7031
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 4096, 'hidden2': 256, 'lr': 0.0005}
# Val F1: 0.6742
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 4096, 'lr': 0.001}
# Val F1: 0.7557
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 4096, 'lr': 0.0005}
# Val F1: 0.7455
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 2048, 'lr': 0.001}
# Val F1: 0.7463
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 2048, 'lr': 0.0005}
# Val F1: 0.7310
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 1024, 'lr': 0.001}
# Val F1: 0.7313
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 1024, 'lr': 0.0005}
# Val F1: 0.7123
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 512, 'lr': 0.001}
# Val F1: 0.7128
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 512, 'lr': 0.0005}
# Val F1: 0.6884
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 256, 'lr': 0.001}
# Val F1: 0.6888
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 2048, 'hidden2': 256, 'lr': 0.0005}
# Val F1: 0.6562
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 4096, 'lr': 0.001}
# Val F1: 0.7459
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 4096, 'lr': 0.0005}
# Val F1: 0.7255
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 2048, 'lr': 0.001}
# Val F1: 0.7376
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 2048, 'lr': 0.0005}
# Val F1: 0.7096
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 1024, 'lr': 0.001}
# Val F1: 0.7215
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 1024, 'lr': 0.0005}
# Val F1: 0.6943
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 512, 'lr': 0.001}
# Val F1: 0.7039
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 512, 'lr': 0.0005}
# Val F1: 0.6743
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 256, 'lr': 0.001}
# Val F1: 0.6770
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 1024, 'hidden2': 256, 'lr': 0.0005}
# Val F1: 0.6359
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 4096, 'lr': 0.001}
# Val F1: 0.7309
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 4096, 'lr': 0.0005}
# Val F1: 0.7063
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 2048, 'lr': 0.001}
# Val F1: 0.7170
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 2048, 'lr': 0.0005}
# Val F1: 0.6857
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 1024, 'lr': 0.001}
# Val F1: 0.7012
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 1024, 'lr': 0.0005}
# Val F1: 0.6700
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 512, 'lr': 0.001}
# Val F1: 0.6796
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 512, 'lr': 0.0005}
# Val F1: 0.6426
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 256, 'lr': 0.001}
# Val F1: 0.6518
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 512, 'hidden2': 256, 'lr': 0.0005}
# Val F1: 0.6112
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 4096, 'lr': 0.001}
# Val F1: 0.7002
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 4096, 'lr': 0.0005}
# Val F1: 0.6713
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 2048, 'lr': 0.001}
# Val F1: 0.6906
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 2048, 'lr': 0.0005}
# Val F1: 0.6557
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 1024, 'lr': 0.001}
# Val F1: 0.6744
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 1024, 'lr': 0.0005}
# Val F1: 0.6392
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 512, 'lr': 0.001}
# Val F1: 0.6478
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 512, 'lr': 0.0005}
# Val F1: 0.6072
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 256, 'lr': 0.001}
# Val F1: 0.6257
#
# Training with config: {'batch_size': 128, 'dropout': 0.3, 'hidden1': 256, 'hidden2': 256, 'lr': 0.0005}
# Val F1: 0.5745
#
# Training with config: {'batch_size': 128, 'dropout': 0.5, 'hidden1': 4096, 'hidden2': 4096, 'lr': 0.001}
# Val F1: 0.7399
#
# Training with config: {'batch_size': 128, 'dropout': 0.5, 'hidden1': 4096, 'hidden2': 4096, 'lr': 0.0005}
# Val F1: 0.7386
#
# Training with config: {'batch_size': 128, 'dropout': 0.5, 'hidden1': 4096, 'hidden2': 2048, 'lr': 0.001}
# Val F1: 0.7298
#
# Training with config: {'batch_size': 128, 'dropout': 0.5, 'hidden1': 4096, 'hidden2': 2048, 'lr': 0.0005}
# Val F1: 0.7239
#
# Training with config: {'batch_size': 128, 'dropout': 0.5, 'hidden1': 4096, 'hidden2': 1024, 'lr': 0.001}
# Val F1: 0.7120
#
# Training with config: {'batch_size': 128, 'dropout': 0.5, 'hidden1': 4096, 'hidden2': 1024, 'lr': 0.0005}
# Val F1: 0.7031
#
# Training with config: {'batch_size': 128, 'dropout': 0.5, 'hidden1': 4096, 'hidden2': 512, 'lr': 0.001}
# Val F1: 0.6976
#
# Training with config: {'batch_size': 128, 'dropout': 0.5, 'hidden1': 4096, 'hidden2': 512, 'lr': 0.0005}
# Val F1: 0.6812
#
# Training with config: {'batch_size': 128, 'dropout': 0.5, 'hidden1': 4096, 'hidden2': 256, 'lr': 0.001}

# %%
# ACTUAL CLASSIFIER

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score


cpp_diffs = np.array(cpp_diffs)

all_labels = sorted(set(l for sample in mapped_data for l in sample))
label_to_idx = {label: idx for idx, label in enumerate(all_labels)}
idx_to_label = {idx: label for label, idx in label_to_idx.items()}
n_labels = len(label_to_idx)


n_samples = len(mapped_data)
y_multi_hot = np.zeros((n_samples, n_labels), dtype=np.float32)
for i, labels in enumerate(mapped_data):
    for label in labels:
        y_multi_hot[i, label_to_idx[label]] = 1.0


X_temp, X_test, y_temp, y_test = train_test_split(
    cpp_diffs, y_multi_hot, test_size=0.2, random_state=42
)


X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.2, random_state=42
)

class MultiLabelDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X).float()
        self.y = torch.from_numpy(y).float()
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

batch_size = 256
train_ds = MultiLabelDataset(X_train, y_train)
val_ds = MultiLabelDataset(X_val, y_val)
test_ds = MultiLabelDataset(X_test, y_test)

train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=4)
val_dl = DataLoader(val_ds, batch_size=batch_size, num_workers=4)
test_dl = DataLoader(test_ds, batch_size=batch_size, num_workers=4)


class MultiLabelNN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 4096),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(4096, output_dim),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.net(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MultiLabelNN(1024, n_labels).to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

train_losses = []
val_losses = []
train_f1s = []
val_f1s = []

n_epochs = 30
for epoch in range(1, n_epochs+1):
    model.train()
    train_loss = 0.0
    all_train_preds = []
    all_train_targets = []

    for xb, yb in train_dl:
        xb = xb.to(device)
        yb = yb.to(device)

        optimizer.zero_grad()
        preds = model(xb)
        loss = criterion(preds, yb)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * xb.size(0)
        all_train_preds.append(preds.detach().cpu())
        all_train_targets.append(yb.cpu())

    train_loss /= len(train_ds)
    train_preds = torch.cat(all_train_preds).numpy()
    train_targets = torch.cat(all_train_targets).numpy()

    model.eval()
    val_loss = 0.0
    all_val_preds = []
    all_val_targets = []

    with torch.no_grad():
        for xb, yb in val_dl:
            xb = xb.to(device)
            yb = yb.to(device)
            preds = model(xb)
            loss = criterion(preds, yb)
            val_loss += loss.item() * xb.size(0)
            all_val_preds.append(preds.cpu())
            all_val_targets.append(yb.cpu())

    val_loss /= len(val_ds)
    val_preds = torch.cat(all_val_preds).numpy()
    val_targets = torch.cat(all_val_targets).numpy()

    train_preds_bin = (train_preds >= 0.5).astype(int)
    val_preds_bin = (val_preds >= 0.5).astype(int)

    train_f1 = f1_score(train_targets, train_preds_bin, average='micro', zero_division=0)
    val_f1 = f1_score(val_targets, val_preds_bin, average='micro', zero_division=0)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_f1s.append(train_f1)
    val_f1s.append(val_f1)

    print(f"Epoch {epoch:02d}: "
          f"Train Loss={train_loss:.4f} F1={train_f1:.4f} "
          f"Val Loss={val_loss:.4f} F1={val_f1:.4f}")
# Out:
# Epoch 01: Train Loss=0.0580 F1=0.3588 Val Loss=0.0404 F1=0.5572
# Epoch 02: Train Loss=0.0369 F1=0.6087 Val Loss=0.0342 F1=0.6404
# Epoch 03: Train Loss=0.0318 F1=0.6712 Val Loss=0.0313 F1=0.6793
# Epoch 04: Train Loss=0.0286 F1=0.7081 Val Loss=0.0297 F1=0.7032
# Epoch 05: Train Loss=0.0261 F1=0.7357 Val Loss=0.0286 F1=0.7185
# Epoch 06: Train Loss=0.0240 F1=0.7580 Val Loss=0.0279 F1=0.7306
# Epoch 07: Train Loss=0.0221 F1=0.7780 Val Loss=0.0275 F1=0.7373
# Epoch 08: Train Loss=0.0205 F1=0.7945 Val Loss=0.0270 F1=0.7478
# Epoch 09: Train Loss=0.0190 F1=0.8104 Val Loss=0.0269 F1=0.7516
# Epoch 10: Train Loss=0.0178 F1=0.8232 Val Loss=0.0269 F1=0.7550
# Epoch 11: Train Loss=0.0165 F1=0.8367 Val Loss=0.0272 F1=0.7594
# Epoch 12: Train Loss=0.0154 F1=0.8481 Val Loss=0.0275 F1=0.7617
# Epoch 13: Train Loss=0.0145 F1=0.8573 Val Loss=0.0278 F1=0.7625
# Epoch 14: Train Loss=0.0136 F1=0.8670 Val Loss=0.0274 F1=0.7681
# Epoch 15: Train Loss=0.0128 F1=0.8748 Val Loss=0.0281 F1=0.7700
# Epoch 16: Train Loss=0.0122 F1=0.8821 Val Loss=0.0286 F1=0.7705
# Epoch 17: Train Loss=0.0116 F1=0.8884 Val Loss=0.0288 F1=0.7716
# Epoch 18: Train Loss=0.0110 F1=0.8940 Val Loss=0.0295 F1=0.7714
# Epoch 19: Train Loss=0.0105 F1=0.8993 Val Loss=0.0300 F1=0.7727
# Epoch 20: Train Loss=0.0100 F1=0.9043 Val Loss=0.0305 F1=0.7743
# Epoch 21: Train Loss=0.0096 F1=0.9089 Val Loss=0.0307 F1=0.7754
# Epoch 22: Train Loss=0.0092 F1=0.9120 Val Loss=0.0310 F1=0.7747
# Epoch 23: Train Loss=0.0089 F1=0.9159 Val Loss=0.0319 F1=0.7753
# Epoch 24: Train Loss=0.0086 F1=0.9183 Val Loss=0.0322 F1=0.7751
# Epoch 25: Train Loss=0.0083 F1=0.9221 Val Loss=0.0328 F1=0.7743
# Epoch 26: Train Loss=0.0081 F1=0.9243 Val Loss=0.0327 F1=0.7765
# Epoch 27: Train Loss=0.0079 F1=0.9268 Val Loss=0.0325 F1=0.7759
# Epoch 28: Train Loss=0.0076 F1=0.9293 Val Loss=0.0336 F1=0.7768
# Epoch 29: Train Loss=0.0074 F1=0.9310 Val Loss=0.0346 F1=0.7784
# Epoch 30: Train Loss=0.0072 F1=0.9335 Val Loss=0.0348 F1=0.7785

# %%
# Training performance plots

import matplotlib.pyplot as plt
# %matplotlib inline
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Loss plot
ax1.plot(range(1, n_epochs+1), train_losses, label='Train Loss', marker='o')
ax1.plot(range(1, n_epochs+1), val_losses, label='Val Loss', marker='o')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training and Validation Loss')
ax1.legend()
ax1.grid(True)

# F1 Score plot
ax2.plot(range(1, n_epochs+1), train_f1s, label='Train F1', marker='o')
ax2.plot(range(1, n_epochs+1), val_f1s, label='Val F1', marker='o')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('F1 Score')
ax2.set_title('Training and Validation F1 Score')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
# Performance eval for either micro or macro F1
model.eval()
test_loss = 0.0
all_test_preds = []
all_test_targets = []

with torch.no_grad():
    for xb, yb in test_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        preds = model(xb)
        loss = criterion(preds, yb)
        test_loss += loss.item() * xb.size(0)
        all_test_preds.append(preds.cpu())
        all_test_targets.append(yb.cpu())

test_loss /= len(test_ds)
test_preds = torch.cat(all_test_preds).numpy()
test_targets = torch.cat(all_test_targets).numpy()
test_preds_bin = (test_preds >= 0.5).astype(int)
test_f1 = f1_score(test_targets, test_preds_bin, average='micro', zero_division=0)

print(f"\nTest Loss={test_loss:.4f} F1 Score={test_f1:.4f}")
# Out:
# Test Loss=0.0347 F1 Score=0.7789
